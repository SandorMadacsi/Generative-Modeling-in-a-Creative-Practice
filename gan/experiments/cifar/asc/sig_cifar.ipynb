# %%
from tensorflow import keras
import tensorflow as tf
from lib.utils import model, gan, build
import matplotlib.pyplot as plt

# %% [markdown]
# # Ascending Cifar10 models with sigmoid activation

# %%
(x,y), (_,_) = keras.datasets.cifar10.load_data()
dataset = x[y.flatten() == 2]
plt.imshow((dataset).astype('int32')[1])
dataset = dataset.reshape((dataset.shape[0],)+ (32,32,3)) .astype('float32') /255.

# %%
res = 32
channel = 3
# Preprocessing data with custom function
batch_size = 64
img_shape = (res,res,channel)
epochs = 200
latent_dim = 100
n_images = 16
s = tf.random.normal([n_images, latent_dim])
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
image_dir = "../../../oDig/cifar/asc/sig/"
checkpoint_dir = '../../../checkpoints/cifar_checkpoints/asc/sig/'
image_freq = 50
checkpoint_freq =200
d_optimizer = build.d_optimizer(0.0002)
g_optimizer = build.g_optimizer(0.0002)

# %%
name = 'Model_1-Sig'
model1 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen1, disc1 = model.build(model1)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 1024)              103424
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1024)              0
#
#  reshape (Reshape)           (None, 8, 8, 16)          0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 32)       8224
#  nspose)
#
#  leaky_re_lu (LeakyReLU)     (None, 16, 16, 32)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 64)       32832
#  ranspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 3)        1731
#  ranspose)
#
# =================================================================
# Total params: 146,211
# Trainable params: 146,211
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 16)        784
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 16, 16, 16)        0
#
#  conv2d (Conv2D)             (None, 8, 8, 32)          8224
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 8, 8, 32)          0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 11,057
# Trainable params: 11,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen1, d=disc1, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 9ms/step - d_loss: 0.6918 - g_loss: 0.6472

# %%
name = 'Model_2-Sig'
model2 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen2, disc2 = model.build(model2)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100)]             0
#
#  dense_2 (Dense)             (None, 2048)              206848
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 2048)              0
#
#  reshape_1 (Reshape)         (None, 8, 8, 32)          0
#
#  conv2d_transpose_3 (Conv2DT  (None, 16, 16, 64)       32832
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 32, 32, 128)      131200
#  ranspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  conv2d_transpose_5 (Conv2DT  (None, 32, 32, 3)        3459
#  ranspose)
#
# =================================================================
# Total params: 374,339
# Trainable params: 374,339
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen2, d=disc2, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 12ms/step - d_loss: 0.6913 - g_loss: 0.6543

# %%
name = 'Model_3-Sig'
model3 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen3, disc3 = model.build(model3)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100)]             0
#
#  dense_4 (Dense)             (None, 4096)              413696
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 4096)              0
#
#  reshape_2 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_6 (Conv2DT  (None, 16, 16, 128)      131200
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_7 (Conv2DT  (None, 32, 32, 256)      524544
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_8 (Conv2DT  (None, 32, 32, 3)        6915
#  ranspose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen3, d=disc3, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.6921 - g_loss: 0.6449

# %%
name = 'Model_4-Sig'
model4 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen4, disc4 = model.build(model4)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100)]             0
#
#  dense_6 (Dense)             (None, 4096)              413696
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 4096)              0
#
#  reshape_3 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_9 (Conv2DT  (None, 16, 16, 128)      131200
#  ranspose)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_10 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_11 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        3136
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         131200
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dropout_3 (Dropout)         (None, 8192)              0
#
#  dense_7 (Dense)             (None, 1)                 8193
#
# =================================================================
# Total params: 142,529
# Trainable params: 142,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen4, d=disc4, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.6931 - g_loss: 0.6493

# %%
name = 'Model_5-Sig'
model5 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen5, disc5 = model.build(model5)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 4096)              413696
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 4096)              0
#
#  reshape_4 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_12 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_13 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_14 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       6272
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)         524544
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  flatten_4 (Flatten)         (None, 16384)             0
#
#  dropout_4 (Dropout)         (None, 16384)             0
#
#  dense_9 (Dense)             (None, 1)                 16385
#
# =================================================================
# Total params: 547,201
# Trainable params: 547,201
# Non-trainable params: 0
# _________________________________________________________________
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 100)]             0
#
#  dense_10 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 4096)              0
#
#  reshape_5 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_15 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_16 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_17 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)       6272
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 256)         524544
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  flatten_5 (Flatten)         (None, 16384)             0
#
#  dropout_5 (Dropout)         (None, 16384)             0
#
#  dense_11 (Dense)            (None, 1)                 16385
#
# =================================================================
# Total params: 547,201
# Trainable params: 547,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen5, d=disc5, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 5s 30ms/step - d_loss: 0.6823 - g_loss: 0.6873

# %%
name = 'Model_6-Sig'
model6 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen6, disc6 = model.build(model6)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100)]             0
#
#  dense_2 (Dense)             (None, 1024)              103424
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 1024)              0
#
#  reshape_1 (Reshape)         (None, 8, 8, 16)          0
#
#  conv2d_transpose_3 (Conv2DT  (None, 16, 16, 32)       8224
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 32)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 32, 32, 64)       32832
#  ranspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 32, 32, 3)        1731
#  ranspose)
#
# =================================================================
# Total params: 146,211
# Trainable params: 146,211
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        784
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 16, 16, 16)        0
#
#  dropout_3 (Dropout)         (None, 16, 16, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 32)          8224
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 8, 8, 32)          0
#
#  dropout_2 (Dropout)         (None, 8, 8, 32)          0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 11,057
# Trainable params: 11,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen6, d=disc6, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 9ms/step - d_loss: 0.6926 - g_loss: 0.6471

# %%
name = 'Model_7-Sig'
model7 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen7, disc7 = model.build(model7)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100)]             0
#
#  dense_4 (Dense)             (None, 2048)              206848
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 2048)              0
#
#  reshape_2 (Reshape)         (None, 8, 8, 32)          0
#
#  conv2d_transpose_6 (Conv2DT  (None, 16, 16, 64)       32832
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_transpose_7 (Conv2DT  (None, 32, 32, 128)      131200
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  conv2d_transpose_8 (Conv2DT  (None, 32, 32, 3)        3459
#  ranspose)
#
# =================================================================
# Total params: 374,339
# Trainable params: 374,339
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  dropout_5 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  dropout_4 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen7, d=disc7, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.6924 - g_loss: 0.6489

# %%
name = 'Model_8-Sig'
model8 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen8, disc8 = model.build(model8)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100)]             0
#
#  dense_6 (Dense)             (None, 4096)              413696
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 4096)              0
#
#  reshape_3 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_9 (Conv2DT  (None, 16, 16, 128)      131200
#  ranspose)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_10 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_11 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  dropout_7 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  dropout_6 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen8, d=disc8, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.6927 - g_loss: 0.6467

# %%
name = 'Model_9-Sig'
model9 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen9, disc9 = model.build(model9)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 4096)              413696
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 4096)              0
#
#  reshape_4 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_12 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_13 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_14 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        3136
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  dropout_9 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         131200
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  dropout_8 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten_4 (Flatten)         (None, 8192)              0
#
#  dense_9 (Dense)             (None, 1)                 8193
#
# =================================================================
# Total params: 142,529
# Trainable params: 142,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen9, d=disc9, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.6897 - g_loss: 0.6556

# %%
name = 'Model_10-Sig'
model10 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen10, disc10 = model.build(model10)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 100)]             0
#
#  dense_10 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 4096)              0
#
#  reshape_5 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_15 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_16 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_17 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)       6272
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  dropout_11 (Dropout)        (None, 16, 16, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 256)         524544
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  dropout_10 (Dropout)        (None, 8, 8, 256)         0
#
#  flatten_5 (Flatten)         (None, 16384)             0
#
#  dense_11 (Dense)            (None, 1)                 16385
#
# =================================================================
# Total params: 547,201
# Trainable params: 547,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen10, d=disc10, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 5s 31ms/step - d_loss: 0.6825 - g_loss: 0.6929

# %%
name = 'Model_11-Sig-Norm'
model1 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen1, disc1 = model.build(model1)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100)]             0
#
#  dense_6 (Dense)             (None, 1024)              103424
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 1024)              0
#
#  reshape_3 (Reshape)         (None, 8, 8, 16)          0
#
#  conv2d_transpose_9 (Conv2DT  (None, 16, 16, 32)       8224
#  ranspose)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  conv2d_transpose_10 (Conv2D  (None, 32, 32, 64)       32832
#  Transpose)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_11 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 146,211
# Trainable params: 146,211
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 16)        784
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 16)        0
#
#  batch_normalization_1 (Batc  (None, 16, 16, 16)       64
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 32)          8224
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 8, 8, 32)          0
#
#  batch_normalization (BatchN  (None, 8, 8, 32)         128
#  ormalization)
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_7 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 11,249
# Trainable params: 11,153
# Non-trainable params: 96
# _________________________________________________________________

# %%
g = gan.GAN(g=gen1, d=disc1, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 8ms/step - d_loss: 0.6928 - g_loss: 0.6493

# %%
name = 'Model_12-Sig-Norm'
model2 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen2, disc2 = model.build(model2)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 2048)              206848
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 2048)              0
#
#  reshape_4 (Reshape)         (None, 8, 8, 32)          0
#
#  conv2d_transpose_12 (Conv2D  (None, 16, 16, 64)       32832
#  Transpose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_transpose_13 (Conv2D  (None, 32, 32, 128)      131200
#  Transpose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  conv2d_transpose_14 (Conv2D  (None, 32, 32, 3)        3459
#  Transpose)
#
# =================================================================
# Total params: 374,339
# Trainable params: 374,339
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  flatten_4 (Flatten)         (None, 4096)              0
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_9 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen2, d=disc2, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 12ms/step - d_loss: 0.6925 - g_loss: 0.6465

# %%
name = 'Model_13-Sig-Norm'
model3 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen3, disc3 = model.build(model3)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 100)]             0
#
#  dense_10 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 4096)              0
#
#  reshape_5 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_15 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_16 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_17 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 32)        1568
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_5 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 64)          32832
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  flatten_5 (Flatten)         (None, 4096)              0
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_11 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen3, d=disc3, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 23ms/step - d_loss: 0.6921 - g_loss: 0.6453

# %%
name = 'Model_14-Sig-Norm'
model4 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen4, disc4 = model.build(model4)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 100)]             0
#
#  dense_12 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 4096)              0
#
#  reshape_6 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_18 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_19 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_20 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 64)        3136
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  batch_normalization_7 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)         131200
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  batch_normalization_6 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  flatten_6 (Flatten)         (None, 8192)              0
#
#  dropout_6 (Dropout)         (None, 8192)              0
#
#  dense_13 (Dense)            (None, 1)                 8193
#
# =================================================================
# Total params: 143,297
# Trainable params: 142,913
# Non-trainable params: 384
# _________________________________________________________________

# %%
g = gan.GAN(g=gen4, d=disc4, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.6930 - g_loss: 0.6522

# %%
name = 'Model_15-Sig-Norm'
model5 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen5, disc5 = model.build(model5)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 4096)              413696
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 4096)              0
#
#  reshape (Reshape)           (None, 8, 8, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 128)      131200
#  nspose)
#
#  leaky_re_lu (LeakyReLU)     (None, 16, 16, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 256)      524544
#  ranspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 3)        6915
#  ranspose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 128)       6272
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  batch_normalization_1 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d (Conv2D)             (None, 8, 8, 256)         524544
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  batch_normalization (BatchN  (None, 8, 8, 256)        1024
#  ormalization)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dropout (Dropout)           (None, 16384)             0
#
#  dense_1 (Dense)             (None, 1)                 16385
#
# =================================================================
# Total params: 548,737
# Trainable params: 547,969
# Non-trainable params: 768
# _________________________________________________________________

# %%
g = gan.GAN(g=gen5, d=disc5, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 5s 32ms/step - d_loss: 0.6775 - g_loss: 0.7263

# %%
name = 'Model_16-Sig-Norm'
model6 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen6, disc6 = model.build(model6)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 100)]             0
#
#  dense_12 (Dense)            (None, 1024)              103424
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 1024)              0
#
#  reshape_6 (Reshape)         (None, 8, 8, 16)          0
#
#  conv2d_transpose_18 (Conv2D  (None, 16, 16, 32)       8224
#  Transpose)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  conv2d_transpose_19 (Conv2D  (None, 32, 32, 64)       32832
#  Transpose)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_20 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 146,211
# Trainable params: 146,211
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 16)        784
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 16, 16, 16)        0
#
#  batch_normalization_1 (Batc  (None, 16, 16, 16)       64
#  hNormalization)
#
#  dropout_13 (Dropout)        (None, 16, 16, 16)        0
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 32)          8224
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 8, 8, 32)          0
#
#  batch_normalization (BatchN  (None, 8, 8, 32)         128
#  ormalization)
#
#  dropout_12 (Dropout)        (None, 8, 8, 32)          0
#
#  flatten_6 (Flatten)         (None, 2048)              0
#
#  dense_13 (Dense)            (None, 1)                 2049
#
# =================================================================
# Total params: 11,249
# Trainable params: 11,153
# Non-trainable params: 96
# _________________________________________________________________

# %%
g = gan.GAN(g=gen6, d=disc6, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 10ms/step - d_loss: 0.6915 - g_loss: 0.6482

# %%
name = 'Model_17-Sig-Norm'
model7 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen7, disc7 = model.build(model7)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 100)]             0
#
#  dense_14 (Dense)            (None, 2048)              206848
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 2048)              0
#
#  reshape_7 (Reshape)         (None, 8, 8, 32)          0
#
#  conv2d_transpose_21 (Conv2D  (None, 16, 16, 64)       32832
#  Transpose)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_transpose_22 (Conv2D  (None, 32, 32, 128)      131200
#  Transpose)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  conv2d_transpose_23 (Conv2D  (None, 32, 32, 3)        3459
#  Transpose)
#
# =================================================================
# Total params: 374,339
# Trainable params: 374,339
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 32)        1568
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  dropout_15 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 64)          32832
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_14 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_7 (Flatten)         (None, 4096)              0
#
#  dense_15 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen7, d=disc7, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6929 - g_loss: 0.6478

# %%
name = 'Model_18-Sig-Norm'
model8 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen8, disc8 = model.build(model8)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 100)]             0
#
#  dense_16 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 4096)              0
#
#  reshape_8 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_24 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_25 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_26 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 32)        1568
#
#  leaky_re_lu_44 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_5 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  dropout_17 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 64)          32832
#
#  leaky_re_lu_43 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_16 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_8 (Flatten)         (None, 4096)              0
#
#  dense_17 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen8, d=disc8, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 27ms/step - d_loss: 0.6922 - g_loss: 0.6450

# %%
name = 'Model_19-Sig-Norm'
model9 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen9, disc9 = model.build(model9)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 100)]             0
#
#  dense_18 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_47 (LeakyReLU)  (None, 4096)              0
#
#  reshape_9 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_27 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_45 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_28 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_46 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_29 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 64)        3136
#
#  leaky_re_lu_49 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  batch_normalization_7 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  dropout_19 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 128)         131200
#
#  leaky_re_lu_48 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  batch_normalization_6 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  dropout_18 (Dropout)        (None, 8, 8, 128)         0
#
#  flatten_9 (Flatten)         (None, 8192)              0
#
#  dense_19 (Dense)            (None, 1)                 8193
#
# =================================================================
# Total params: 143,297
# Trainable params: 142,913
# Non-trainable params: 384
# _________________________________________________________________

# %%
g = gan.GAN(g=gen9, d=disc9, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 24ms/step - d_loss: 0.6913 - g_loss: 0.6492

# %%
name = 'Model_20-Sig-Norm'
model10 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=1,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=False
                              )
gen10, disc10 = model.build(model10)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 100)]             0
#
#  dense_20 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_52 (LeakyReLU)  (None, 4096)              0
#
#  reshape_10 (Reshape)        (None, 8, 8, 64)          0
#
#  conv2d_transpose_30 (Conv2D  (None, 16, 16, 128)      131200
#  Transpose)
#
#  leaky_re_lu_50 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_31 (Conv2D  (None, 32, 32, 256)      524544
#  Transpose)
#
#  leaky_re_lu_51 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_32 (Conv2D  (None, 32, 32, 3)        6915
#  Transpose)
#
# =================================================================
# Total params: 1,076,355
# Trainable params: 1,076,355
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 128)       6272
#
#  leaky_re_lu_54 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  batch_normalization_9 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  dropout_21 (Dropout)        (None, 16, 16, 128)       0
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 256)         524544
#
#  leaky_re_lu_53 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  batch_normalization_8 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  dropout_20 (Dropout)        (None, 8, 8, 256)         0
#
#  flatten_10 (Flatten)        (None, 16384)             0
#
#  dense_21 (Dense)            (None, 1)                 16385
#
# =================================================================
# Total params: 548,737
# Trainable params: 547,969
# Non-trainable params: 768
# _________________________________________________________________

# %%
g = gan.GAN(g=gen10, d=disc10, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 5s 31ms/step - d_loss: 0.6807 - g_loss: 0.7028
