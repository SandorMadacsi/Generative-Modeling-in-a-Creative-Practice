# %%
from tensorflow import keras
import tensorflow as tf
from lib.utils import model, gan, build
import matplotlib.pyplot as plt

# %% [markdown]
# # Descending Cifar10 models with stanh activation

# %%
(x,y), (_,_) = keras.datasets.cifar10.load_data()
dataset = x[y.flatten() == 2]
plt.imshow((dataset).astype('int32')[1])
dataset = dataset.reshape((dataset.shape[0],)+ (32,32,3)) .astype('float32') /127.5 - 1.0

# %%
res = 32
channel = 3
# Preprocessing data with custom function
batch_size = 64
img_shape = (res,res,channel)
epochs = 200
latent_dim = 100
n_images = 16
s = tf.random.normal([n_images, latent_dim])
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
image_dir = "../../../oDig/cifar/desc/tanh/"
checkpoint_dir = '../../../checkpoints/cifar_checkpoints/desc/tanh/'
image_freq = 50
checkpoint_freq =200
d_optimizer = build.d_optimizer(0.0002)
g_optimizer = build.g_optimizer(0.0002)
# Out:
# 2022-04-08 11:43:27.406848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.416699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.417072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.417802: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-08 11:43:27.418185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.418913: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.419635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.770854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.771199: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.771515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-08 11:43:27.771823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4082 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:0a:00.0, compute capability: 7.5

# %%
name = 'Model_1-Tanh'
model1 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen1, disc1 = model.build(model1)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 4096)              413696
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 4096)              0
#
#  reshape (Reshape)           (None, 8, 8, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 32)       32800
#  nspose)
#
#  leaky_re_lu (LeakyReLU)     (None, 16, 16, 32)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 16)       8208
#  ranspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32, 32, 16)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 3)        435
#  ranspose)
#
# =================================================================
# Total params: 455,139
# Trainable params: 455,139
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 16)        784
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 16, 16, 16)        0
#
#  conv2d (Conv2D)             (None, 8, 8, 32)          8224
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 8, 8, 32)          0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 11,057
# Trainable params: 11,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen1, d=disc1, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 9ms/step - d_loss: 0.6898 - g_loss: 0.6654

# %%
name = 'Model_2-Tanh'
model2 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen2, disc2 = model.build(model2)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100)]             0
#
#  dense_2 (Dense)             (None, 8192)              827392
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8192)              0
#
#  reshape_1 (Reshape)         (None, 8, 8, 128)         0
#
#  conv2d_transpose_3 (Conv2DT  (None, 16, 16, 64)       131136
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 32, 32, 32)       32800
#  ranspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 32)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 32, 32, 3)        867
#  ranspose)
#
# =================================================================
# Total params: 992,195
# Trainable params: 992,195
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen2, d=disc2, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 9ms/step - d_loss: 0.6925 - g_loss: 0.6589

# %%
name = 'Model_3-Tanh'
model3 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen3, disc3 = model.build(model3)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100)]             0
#
#  dense_4 (Dense)             (None, 16384)             1654784
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 16384)             0
#
#  reshape_2 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_6 (Conv2DT  (None, 16, 16, 128)      524416
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_7 (Conv2DT  (None, 32, 32, 64)       131136
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_8 (Conv2DT  (None, 32, 32, 3)        1731
#  ranspose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen3, d=disc3, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 16ms/step - d_loss: 0.6928 - g_loss: 0.6474

# %%
name = 'Model_4-Tanh'
model4 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen4, disc4 = model.build(model4)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100)]             0
#
#  dense_6 (Dense)             (None, 16384)             1654784
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 16384)             0
#
#  reshape_3 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_9 (Conv2DT  (None, 16, 16, 128)      524416
#  ranspose)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_10 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_11 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        3136
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         131200
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dropout_3 (Dropout)         (None, 8192)              0
#
#  dense_7 (Dense)             (None, 1)                 8193
#
# =================================================================
# Total params: 142,529
# Trainable params: 142,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen4, d=disc4, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 16ms/step - d_loss: 0.6897 - g_loss: 0.6634

# %%
name = 'Model_5-Tanh'
model5 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen5, disc5 = model.build(model5)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 16384)             1654784
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 16384)             0
#
#  reshape_4 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_12 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_13 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_14 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       6272
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)         524544
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  flatten_4 (Flatten)         (None, 16384)             0
#
#  dropout_4 (Dropout)         (None, 16384)             0
#
#  dense_9 (Dense)             (None, 1)                 16385
#
# =================================================================
# Total params: 547,201
# Trainable params: 547,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen5, d=disc5, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 21ms/step - d_loss: 0.6494 - g_loss: 0.7904

# %%
name = 'Model_6-Tanh'
model6 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen6, disc6 = model.build(model6)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 4096)              413696
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 4096)              0
#
#  reshape (Reshape)           (None, 8, 8, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 32)       32800
#  nspose)
#
#  leaky_re_lu (LeakyReLU)     (None, 16, 16, 32)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 16)       8208
#  ranspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32, 32, 16)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 3)        435
#  ranspose)
#
# =================================================================
# Total params: 455,139
# Trainable params: 455,139
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 16)        784
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 16, 16, 16)        0
#
#  dropout_1 (Dropout)         (None, 16, 16, 16)        0
#
#  conv2d (Conv2D)             (None, 8, 8, 32)          8224
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 8, 8, 32)          0
#
#  dropout (Dropout)           (None, 8, 8, 32)          0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 11,057
# Trainable params: 11,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen6, d=disc6, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 8ms/step - d_loss: 0.6882 - g_loss: 0.6576

# %%
name = 'Model_7-Tanh'
model7 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen7, disc7 = model.build(model7)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100)]             0
#
#  dense_2 (Dense)             (None, 8192)              827392
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8192)              0
#
#  reshape_1 (Reshape)         (None, 8, 8, 128)         0
#
#  conv2d_transpose_3 (Conv2DT  (None, 16, 16, 64)       131136
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 32, 32, 32)       32800
#  ranspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 32)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 32, 32, 3)        867
#  ranspose)
#
# =================================================================
# Total params: 992,195
# Trainable params: 992,195
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 16, 16, 32)        0
#
#  dropout_3 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  dropout_2 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen7, d=disc7, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 10ms/step - d_loss: 0.6919 - g_loss: 0.6582

# %%
name = 'Model_8-Tanh'
model8 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen8, disc8 = model.build(model8)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100)]             0
#
#  dense_4 (Dense)             (None, 16384)             1654784
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 16384)             0
#
#  reshape_2 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_6 (Conv2DT  (None, 16, 16, 128)      524416
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_7 (Conv2DT  (None, 32, 32, 64)       131136
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_8 (Conv2DT  (None, 32, 32, 3)        1731
#  ranspose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        1568
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  dropout_5 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          32832
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  dropout_4 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen8, d=disc8, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.6925 - g_loss: 0.6483

# %%
name = 'Model_9-Tanh'
model9 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen9, disc9 = model.build(model9)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100)]             0
#
#  dense_6 (Dense)             (None, 16384)             1654784
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 16384)             0
#
#  reshape_3 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_9 (Conv2DT  (None, 16, 16, 128)      524416
#  ranspose)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_10 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_11 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        3136
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  dropout_7 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         131200
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  dropout_6 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dense_7 (Dense)             (None, 1)                 8193
#
# =================================================================
# Total params: 142,529
# Trainable params: 142,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen9, d=disc9, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.6901 - g_loss: 0.6638

# %%
name = 'Model_10-Tanh'
model10 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=False,
                              is_tanh=True
                              )
gen10, disc10 = model.build(model10)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 16384)             1654784
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 16384)             0
#
#  reshape_4 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_12 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_13 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_14 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       6272
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  dropout_9 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)         524544
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  dropout_8 (Dropout)         (None, 8, 8, 256)         0
#
#  flatten_4 (Flatten)         (None, 16384)             0
#
#  dense_9 (Dense)             (None, 1)                 16385
#
# =================================================================
# Total params: 547,201
# Trainable params: 547,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen10, d=disc10, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 21ms/step - d_loss: 0.6559 - g_loss: 0.7746

# %%
name = 'Model_11-Tanh-Norm'
model1 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen1, disc1 = model.build(model1)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 100)]             0
#
#  dense_20 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_52 (LeakyReLU)  (None, 4096)              0
#
#  reshape_10 (Reshape)        (None, 8, 8, 64)          0
#
#  conv2d_transpose_30 (Conv2D  (None, 16, 16, 32)       32800
#  Transpose)
#
#  leaky_re_lu_50 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  conv2d_transpose_31 (Conv2D  (None, 32, 32, 16)       8208
#  Transpose)
#
#  leaky_re_lu_51 (LeakyReLU)  (None, 32, 32, 16)        0
#
#  conv2d_transpose_32 (Conv2D  (None, 32, 32, 3)        435
#  Transpose)
#
# =================================================================
# Total params: 455,139
# Trainable params: 455,139
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 16)        784
#
#  leaky_re_lu_54 (LeakyReLU)  (None, 16, 16, 16)        0
#
#  batch_normalization_1 (Batc  (None, 16, 16, 16)       64
#  hNormalization)
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 32)          8224
#
#  leaky_re_lu_53 (LeakyReLU)  (None, 8, 8, 32)          0
#
#  batch_normalization (BatchN  (None, 8, 8, 32)         128
#  ormalization)
#
#  flatten_10 (Flatten)        (None, 2048)              0
#
#  dropout_10 (Dropout)        (None, 2048)              0
#
#  dense_21 (Dense)            (None, 1)                 2049
#
# =================================================================
# Total params: 11,249
# Trainable params: 11,153
# Non-trainable params: 96
# _________________________________________________________________

# %%
g = gan.GAN(g=gen1, d=disc1, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 8ms/step - d_loss: 0.6931 - g_loss: 0.6542

# %%
name = 'Model_12-Tanh-Norm'
model2 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen2, disc2 = model.build(model2)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 100)]             0
#
#  dense_22 (Dense)            (None, 8192)              827392
#
#  leaky_re_lu_57 (LeakyReLU)  (None, 8192)              0
#
#  reshape_11 (Reshape)        (None, 8, 8, 128)         0
#
#  conv2d_transpose_33 (Conv2D  (None, 16, 16, 64)       131136
#  Transpose)
#
#  leaky_re_lu_55 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_transpose_34 (Conv2D  (None, 32, 32, 32)       32800
#  Transpose)
#
#  leaky_re_lu_56 (LeakyReLU)  (None, 32, 32, 32)        0
#
#  conv2d_transpose_35 (Conv2D  (None, 32, 32, 3)        867
#  Transpose)
#
# =================================================================
# Total params: 992,195
# Trainable params: 992,195
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_23 (Conv2D)          (None, 16, 16, 32)        1568
#
#  leaky_re_lu_59 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 64)          32832
#
#  leaky_re_lu_58 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  flatten_11 (Flatten)        (None, 4096)              0
#
#  dropout_11 (Dropout)        (None, 4096)              0
#
#  dense_23 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen2, d=disc2, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 10ms/step - d_loss: 0.6913 - g_loss: 0.6614

# %%
name = 'Model_13-Tanh-Norm'
model3 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen3, disc3 = model.build(model3)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 100)]             0
#
#  dense_24 (Dense)            (None, 16384)             1654784
#
#  leaky_re_lu_62 (LeakyReLU)  (None, 16384)             0
#
#  reshape_12 (Reshape)        (None, 8, 8, 256)         0
#
#  conv2d_transpose_36 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_60 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_37 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_61 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_38 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 32)        1568
#
#  leaky_re_lu_64 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_5 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 64)          32832
#
#  leaky_re_lu_63 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  flatten_12 (Flatten)        (None, 4096)              0
#
#  dropout_12 (Dropout)        (None, 4096)              0
#
#  dense_25 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen3, d=disc3, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 16ms/step - d_loss: 0.6921 - g_loss: 0.6448

# %%
name = 'Model_14-Tanh-Norm'
model4 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen4, disc4 = model.build(model4)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 100)]             0
#
#  dense_26 (Dense)            (None, 16384)             1654784
#
#  leaky_re_lu_67 (LeakyReLU)  (None, 16384)             0
#
#  reshape_13 (Reshape)        (None, 8, 8, 256)         0
#
#  conv2d_transpose_39 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_65 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_40 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_66 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_41 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 64)        3136
#
#  leaky_re_lu_69 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  batch_normalization_7 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 128)         131200
#
#  leaky_re_lu_68 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  batch_normalization_6 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  flatten_13 (Flatten)        (None, 8192)              0
#
#  dropout_13 (Dropout)        (None, 8192)              0
#
#  dense_27 (Dense)            (None, 1)                 8193
#
# =================================================================
# Total params: 143,297
# Trainable params: 142,913
# Non-trainable params: 384
# _________________________________________________________________

# %%
g = gan.GAN(g=gen4, d=disc4, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.6891 - g_loss: 0.6620

# %%
name = 'Model_15-Tanh-Norm'
model5 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen5, disc5 = model.build(model5)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_29 (InputLayer)       [(None, 100)]             0
#
#  dense_28 (Dense)            (None, 16384)             1654784
#
#  leaky_re_lu_72 (LeakyReLU)  (None, 16384)             0
#
#  reshape_14 (Reshape)        (None, 8, 8, 256)         0
#
#  conv2d_transpose_42 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_70 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_43 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_71 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_44 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 128)       6272
#
#  leaky_re_lu_74 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  batch_normalization_9 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 256)         524544
#
#  leaky_re_lu_73 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  batch_normalization_8 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  flatten_14 (Flatten)        (None, 16384)             0
#
#  dropout_14 (Dropout)        (None, 16384)             0
#
#  dense_29 (Dense)            (None, 1)                 16385
#
# =================================================================
# Total params: 548,737
# Trainable params: 547,969
# Non-trainable params: 768
# _________________________________________________________________

# %%
g = gan.GAN(g=gen5, d=disc5, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.6553 - g_loss: 0.7700

# %%
name = 'Model_16-Tanh-Norm'
model6 = model.ModelSettings(model_name=name,
                              gen_filter=5,
                              disc_filter=5,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen6, disc6 = model.build(model6)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 100)]             0
#
#  dense_10 (Dense)            (None, 4096)              413696
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 4096)              0
#
#  reshape_5 (Reshape)         (None, 8, 8, 64)          0
#
#  conv2d_transpose_15 (Conv2D  (None, 16, 16, 32)       32800
#  Transpose)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  conv2d_transpose_16 (Conv2D  (None, 32, 32, 16)       8208
#  Transpose)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 32, 32, 16)        0
#
#  conv2d_transpose_17 (Conv2D  (None, 32, 32, 3)        435
#  Transpose)
#
# =================================================================
# Total params: 455,139
# Trainable params: 455,139
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 16)        784
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 16, 16, 16)        0
#
#  batch_normalization_1 (Batc  (None, 16, 16, 16)       64
#  hNormalization)
#
#  dropout_11 (Dropout)        (None, 16, 16, 16)        0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 32)          8224
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 8, 8, 32)          0
#
#  batch_normalization (BatchN  (None, 8, 8, 32)         128
#  ormalization)
#
#  dropout_10 (Dropout)        (None, 8, 8, 32)          0
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dense_11 (Dense)            (None, 1)                 2049
#
# =================================================================
# Total params: 11,249
# Trainable params: 11,153
# Non-trainable params: 96
# _________________________________________________________________

# %%
g = gan.GAN(g=gen6, d=disc6, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 1s 9ms/step - d_loss: 0.6896 - g_loss: 0.6620

# %%
name = 'Model_17-Tanh-Norm'
model7 = model.ModelSettings(model_name=name,
                              gen_filter=6,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen7, disc7 = model.build(model7)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 100)]             0
#
#  dense_12 (Dense)            (None, 8192)              827392
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 8192)              0
#
#  reshape_6 (Reshape)         (None, 8, 8, 128)         0
#
#  conv2d_transpose_18 (Conv2D  (None, 16, 16, 64)       131136
#  Transpose)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_transpose_19 (Conv2D  (None, 32, 32, 32)       32800
#  Transpose)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 32, 32, 32)        0
#
#  conv2d_transpose_20 (Conv2D  (None, 32, 32, 3)        867
#  Transpose)
#
# =================================================================
# Total params: 992,195
# Trainable params: 992,195
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 32)        1568
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  dropout_13 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 64)          32832
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_12 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_6 (Flatten)         (None, 4096)              0
#
#  dense_13 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen7, d=disc7, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 2s 11ms/step - d_loss: 0.6884 - g_loss: 0.6614

# %%
name = 'Model_18-Tanh-Norm'
model8 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=6,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen8, disc8 = model.build(model8)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 100)]             0
#
#  dense_14 (Dense)            (None, 16384)             1654784
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 16384)             0
#
#  reshape_7 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_21 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_22 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_23 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 32)        1568
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  batch_normalization_5 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  dropout_15 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 64)          32832
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_14 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_7 (Flatten)         (None, 4096)              0
#
#  dense_15 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 38,881
# Trainable params: 38,689
# Non-trainable params: 192
# _________________________________________________________________

# %%
g = gan.GAN(g=gen8, d=disc8, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.6931 - g_loss: 0.6484

# %%
name = 'Model_19-Tanh-Norm'
model9 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=7,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen9, disc9 = model.build(model9)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 100)]             0
#
#  dense_16 (Dense)            (None, 16384)             1654784
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 16384)             0
#
#  reshape_8 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_24 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_25 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_26 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 64)        3136
#
#  leaky_re_lu_44 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  batch_normalization_7 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  dropout_17 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         131200
#
#  leaky_re_lu_43 (LeakyReLU)  (None, 8, 8, 128)         0
#
#  batch_normalization_6 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  dropout_16 (Dropout)        (None, 8, 8, 128)         0
#
#  flatten_8 (Flatten)         (None, 8192)              0
#
#  dense_17 (Dense)            (None, 1)                 8193
#
# =================================================================
# Total params: 143,297
# Trainable params: 142,913
# Non-trainable params: 384
# _________________________________________________________________

# %%
g = gan.GAN(g=gen9, d=disc9, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.6895 - g_loss: 0.6648

# %%
name = 'Model_20-Tanh-Norm'
model10 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=8,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=True,
                              is_batchnorm=True,
                              is_tanh=True
                              )
gen10, disc10 = model.build(model10)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 100)]             0
#
#  dense_18 (Dense)            (None, 16384)             1654784
#
#  leaky_re_lu_47 (LeakyReLU)  (None, 16384)             0
#
#  reshape_9 (Reshape)         (None, 8, 8, 256)         0
#
#  conv2d_transpose_27 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  leaky_re_lu_45 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_28 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  leaky_re_lu_46 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_29 (Conv2D  (None, 32, 32, 3)        1731
#  Transpose)
#
# =================================================================
# Total params: 2,312,067
# Trainable params: 2,312,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 128)       6272
#
#  leaky_re_lu_49 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  batch_normalization_9 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  dropout_19 (Dropout)        (None, 16, 16, 128)       0
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 256)         524544
#
#  leaky_re_lu_48 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  batch_normalization_8 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  dropout_18 (Dropout)        (None, 8, 8, 256)         0
#
#  flatten_9 (Flatten)         (None, 16384)             0
#
#  dense_19 (Dense)            (None, 1)                 16385
#
# =================================================================
# Total params: 548,737
# Trainable params: 547,969
# Non-trainable params: 768
# _________________________________________________________________

# %%
g = gan.GAN(g=gen10, d=disc10, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs,
      callbacks=[gan.GANCallback(num_img=n_images, iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 157/157 [==============================] - 4s 24ms/step - d_loss: 0.6507 - g_loss: 0.8046
