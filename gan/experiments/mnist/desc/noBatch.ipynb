# %%
from tensorflow import keras
import tensorflow as tf
from lib.utils import model, gan, preprocess, build

# %% [markdown]
# # Descending MNIST Models without batch normalization

# %%
# We only store the training and test data without labels
(x,_), (y,_) = keras.datasets.mnist.load_data()
#resolution and number of channels
res = 28
channel = 1
# Preprocessing data with custom function
batch_size = 64
dataset = preprocess.preprocess_Data(x,y, False,res,channel,b_size=batch_size, isTanh=True)
#Essentials
img_shape = (res,res,channel)
epochs = 30
latent_dim = 100
#number of images to sample
n_images = 16
#seed matrix of random gaussian for tracking the same samples over training
s = tf.random.normal([n_images, latent_dim])
#to calculate losses
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
# directories
checkpoint_dir = '../../../checkpoints/mnist_checkpoints/asc/batch'
image_dir = "../../../oDig/mnist/asc/batch"
image_freq = 10
#optimizers
d_optimizer = build.d_optimizer(0.0002)
g_optimizer = build.g_optimizer(0.0002)
# Out:
# 2022-03-31 12:00:49.554628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:49.582151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:49.582533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:49.583717: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-31 12:00:49.584465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:49.584797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:49.585111: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:50.132482: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:50.132831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:50.133144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:00:50.133453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4198 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:0a:00.0, compute capability: 7.5

# %%
name = 'Model_1-Tanh-MultiDrop'
model1 = model.ModelSettings(model_name= name,
                             gen_filter=5,
                             disc_filter=5,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen1 ,disc1 = model.build(model1)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 3136)              316736
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 3136)              0
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 32)       32800
#  nspose)
#
#  leaky_re_lu (LeakyReLU)     (None, 14, 14, 32)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 16)       8208
#  ranspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 1)        145
#  ranspose)
#
# =================================================================
# Total params: 357,889
# Trainable params: 357,889
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        272
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 14, 14, 16)        0
#
#  dropout_1 (Dropout)         (None, 14, 14, 16)        0
#
#  conv2d (Conv2D)             (None, 7, 7, 32)          8224
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 7, 7, 32)          0
#
#  dropout (Dropout)           (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense_1 (Dense)             (None, 1)                 1569
#
# =================================================================
# Total params: 10,065
# Trainable params: 10,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen1, d = disc1, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 12s 6ms/step - d_loss: 0.6468 - g_loss: 0.7555

# %%
name = 'Model_2-Tanh-MultiDrop'
model2 = model.ModelSettings(model_name=name,
                             gen_filter=6,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen2 ,disc2 = model.build(model2)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100)]             0
#
#  dense_4 (Dense)             (None, 6272)              633472
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 6272)              0
#
#  reshape_2 (Reshape)         (None, 7, 7, 128)         0
#
#  conv2d_transpose_6 (Conv2DT  (None, 14, 14, 64)       131136
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  conv2d_transpose_7 (Conv2DT  (None, 28, 28, 32)       32800
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 28, 28, 32)        0
#
#  conv2d_transpose_8 (Conv2DT  (None, 28, 28, 1)        289
#  ranspose)
#
# =================================================================
# Total params: 797,697
# Trainable params: 797,697
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 32)        544
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  dropout_5 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 64)          32832
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  dropout_4 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_5 (Dense)             (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen2, d = disc2, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 15s 7ms/step - d_loss: 0.6786 - g_loss: 0.6988

# %%
name = 'Model_3-Tanh-MultiDrop'
model3 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen3 ,disc3 = model.build(model3)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 12544)             1266944
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 12544)             0
#
#  reshape_4 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_12 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_13 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_14 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 32)        544
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  dropout_9 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 64)          32832
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  dropout_8 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_9 (Dense)             (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen3, d = disc3, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 27s 12ms/step - d_loss: 0.6894 - g_loss: 0.6660

# %%
name = 'Model_4-Tanh-MultiDrop'
model4 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=7,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen4 ,disc4 = model.build(model4)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 100)]             0
#
#  dense_10 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 12544)             0
#
#  reshape_5 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_15 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_16 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_17 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 64)        1088
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  dropout_11 (Dropout)        (None, 14, 14, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 128)         131200
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 7, 7, 128)         0
#
#  dropout_10 (Dropout)        (None, 7, 7, 128)         0
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#  dense_11 (Dense)            (None, 1)                 6273
#
# =================================================================
# Total params: 138,561
# Trainable params: 138,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen4, d = disc4, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 28s 13ms/step - d_loss: 0.6654 - g_loss: 0.7445

# %%
name = 'Model_5-Tanh-MultiDrop'
model5 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=8,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen5 ,disc5 = model.build(model5)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 100)]             0
#
#  dense_12 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 12544)             0
#
#  reshape_6 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_18 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_19 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_20 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 128)       2176
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  dropout_13 (Dropout)        (None, 14, 14, 128)       0
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 256)         524544
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 7, 7, 256)         0
#
#  dropout_12 (Dropout)        (None, 7, 7, 256)         0
#
#  flatten_6 (Flatten)         (None, 12544)             0
#
#  dense_13 (Dense)            (None, 1)                 12545
#
# =================================================================
# Total params: 539,265
# Trainable params: 539,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen5, d = disc5, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 39s 18ms/step - d_loss: 0.6242 - g_loss: 0.8822

# %%
name = 'Model_6-Tanh-OneDrop'
model6 = model.ModelSettings(model_name= name,
                             gen_filter=5,
                             disc_filter=5,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen6 ,disc6 = model.build(model6)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 100)]             0
#
#  dense_14 (Dense)            (None, 3136)              316736
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 3136)              0
#
#  reshape_7 (Reshape)         (None, 7, 7, 64)          0
#
#  conv2d_transpose_21 (Conv2D  (None, 14, 14, 32)       32800
#  Transpose)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  conv2d_transpose_22 (Conv2D  (None, 28, 28, 16)       8208
#  Transpose)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  conv2d_transpose_23 (Conv2D  (None, 28, 28, 1)        145
#  Transpose)
#
# =================================================================
# Total params: 357,889
# Trainable params: 357,889
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 16)        272
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 14, 14, 16)        0
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 32)          8224
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 7, 7, 32)          0
#
#  flatten_7 (Flatten)         (None, 1568)              0
#
#  dropout_14 (Dropout)        (None, 1568)              0
#
#  dense_15 (Dense)            (None, 1)                 1569
#
# =================================================================
# Total params: 10,065
# Trainable params: 10,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen6, d = disc6, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 g = gan.GAN(g = gen6, d = disc6, b_size=batch_size, l_dim=latent_dim)
#       2 g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
#       3 g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
#
# NameError: name 'gen6' is not defined

# %%
name = 'Model_7-Tanh-OneDrop'
model7 = model.ModelSettings(model_name=name,
                             gen_filter=6,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen7 ,disc7 = model.build(model7)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 6272)              633472
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 6272)              0
#
#  reshape (Reshape)           (None, 7, 7, 128)         0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 64)       131136
#  nspose)
#
#  leaky_re_lu (LeakyReLU)     (None, 14, 14, 64)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       32800
#  ranspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 28, 28, 32)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 1)        289
#  ranspose)
#
# =================================================================
# Total params: 797,697
# Trainable params: 797,697
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        544
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 14, 14, 32)        0
#
#  conv2d (Conv2D)             (None, 7, 7, 64)          32832
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dropout (Dropout)           (None, 3136)              0
#
#  dense_1 (Dense)             (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen7, d = disc7, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 16s 7ms/step - d_loss: 0.6692 - g_loss: 0.7257

# %%
name = 'Model_8-Tanh-OneDrop'
model8 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen8 ,disc8 = model.build(model8)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100)]             0
#
#  dense_2 (Dense)             (None, 12544)             1266944
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 12544)             0
#
#  reshape_1 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_3 (Conv2DT  (None, 14, 14, 128)      524416
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 14, 14, 128)       0
#
#  conv2d_transpose_4 (Conv2DT  (None, 28, 28, 64)       131136
#  ranspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 28, 28, 64)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 28, 28, 1)        577
#  ranspose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        544
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 14, 14, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          32832
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dropout_1 (Dropout)         (None, 3136)              0
#
#  dense_3 (Dense)             (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen8, d = disc8, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 27s 12ms/step - d_loss: 0.6905 - g_loss: 0.6639

# %%
name = 'Model_9-Tanh-OneDrop'
model9 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=7,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen9 ,disc9 = model.build(model9)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100)]             0
#
#  dense_4 (Dense)             (None, 12544)             1266944
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 12544)             0
#
#  reshape_2 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_6 (Conv2DT  (None, 14, 14, 128)      524416
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_7 (Conv2DT  (None, 28, 28, 64)       131136
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_8 (Conv2DT  (None, 28, 28, 1)        577
#  ranspose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 64)        1088
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         131200
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 7, 7, 128)         0
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dropout_2 (Dropout)         (None, 6272)              0
#
#  dense_5 (Dense)             (None, 1)                 6273
#
# =================================================================
# Total params: 138,561
# Trainable params: 138,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen9, d = disc9, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 28s 13ms/step - d_loss: 0.6707 - g_loss: 0.7275

# %%
name = 'Model_10-Tanh-OneDrop'
model10 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=8,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=True
                             )
gen10 ,disc10 = model.build(model10)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100)]             0
#
#  dense_6 (Dense)             (None, 12544)             1266944
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 12544)             0
#
#  reshape_3 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_9 (Conv2DT  (None, 14, 14, 128)      524416
#  ranspose)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_10 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_11 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 128)       2176
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 256)         524544
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 7, 7, 256)         0
#
#  flatten_3 (Flatten)         (None, 12544)             0
#
#  dropout_3 (Dropout)         (None, 12544)             0
#
#  dense_7 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 539,265
# Trainable params: 539,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen10, d = disc10, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 37s 17ms/step - d_loss: 0.6291 - g_loss: 0.8675

# %%
dataset = preprocess.preprocess_Data(x,y, False,res,channel,b_size=batch_size, isTanh=False)

# %%
name = 'Model_11-Sig-MultiDrop'
model11 = model.ModelSettings(model_name= name,
                             gen_filter=5,
                             disc_filter=5,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen11 ,disc11 = model.build(model11)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100)]             0
#
#  dense_8 (Dense)             (None, 3136)              316736
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 3136)              0
#
#  reshape_4 (Reshape)         (None, 7, 7, 64)          0
#
#  conv2d_transpose_12 (Conv2D  (None, 14, 14, 32)       32800
#  Transpose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  conv2d_transpose_13 (Conv2D  (None, 28, 28, 16)       8208
#  Transpose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  conv2d_transpose_14 (Conv2D  (None, 28, 28, 1)        145
#  Transpose)
#
# =================================================================
# Total params: 357,889
# Trainable params: 357,889
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 16)        272
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 14, 14, 16)        0
#
#  dropout_5 (Dropout)         (None, 14, 14, 16)        0
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 32)          8224
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 7, 7, 32)          0
#
#  dropout_4 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten_4 (Flatten)         (None, 1568)              0
#
#  dense_9 (Dense)             (None, 1)                 1569
#
# =================================================================
# Total params: 10,065
# Trainable params: 10,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g = gen11, d = disc11, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 14s 7ms/step - d_loss: 0.6833 - g_loss: 0.6657

# %%
name = 'Model_12-Sig-MultiDrop'
model12 = model.ModelSettings(model_name=name,
                             gen_filter=6,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen12, disc12 = model.build(model12)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 100)]             0
#
#  dense_10 (Dense)            (None, 6272)              633472
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 6272)              0
#
#  reshape_5 (Reshape)         (None, 7, 7, 128)         0
#
#  conv2d_transpose_15 (Conv2D  (None, 14, 14, 64)       131136
#  Transpose)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  conv2d_transpose_16 (Conv2D  (None, 28, 28, 32)       32800
#  Transpose)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 28, 28, 32)        0
#
#  conv2d_transpose_17 (Conv2D  (None, 28, 28, 1)        289
#  Transpose)
#
# =================================================================
# Total params: 797,697
# Trainable params: 797,697
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 32)        544
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  dropout_7 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 64)          32832
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  dropout_6 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_5 (Flatten)         (None, 3136)              0
#
#  dense_11 (Dense)            (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen12, d=disc12, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 15s 7ms/step - d_loss: 0.6822 - g_loss: 0.6790

# %%
name = 'Model_13-Sig-MultiDrop'
model13 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen13, disc13 = model.build(model13)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 100)]             0
#
#  dense_12 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 12544)             0
#
#  reshape_6 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_18 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_19 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_20 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 32)        544
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  dropout_9 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 64)          32832
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  dropout_8 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_6 (Flatten)         (None, 3136)              0
#
#  dense_13 (Dense)            (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen13, d=disc13, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 27s 12ms/step - d_loss: 0.6905 - g_loss: 0.6541

# %%
name = 'Model_14-Sig-MultiDrop'
model14 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=7,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen14, disc14 = model.build(model14)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 100)]             0
#
#  dense_14 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 12544)             0
#
#  reshape_7 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_21 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_22 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_23 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 64)        1088
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  dropout_11 (Dropout)        (None, 14, 14, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 128)         131200
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 7, 7, 128)         0
#
#  dropout_10 (Dropout)        (None, 7, 7, 128)         0
#
#  flatten_7 (Flatten)         (None, 6272)              0
#
#  dense_15 (Dense)            (None, 1)                 6273
#
# =================================================================
# Total params: 138,561
# Trainable params: 138,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen14, d=disc14, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 28s 13ms/step - d_loss: 0.6794 - g_loss: 0.6867

# %%
name = 'Model_15-Sig-MultiDrop'
model15 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=8,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=True,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen15, disc15 = model.build(model15)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 100)]             0
#
#  dense_16 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 12544)             0
#
#  reshape_8 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_24 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_25 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_26 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 128)       2176
#
#  leaky_re_lu_44 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  dropout_13 (Dropout)        (None, 14, 14, 128)       0
#
#  conv2d_16 (Conv2D)          (None, 7, 7, 256)         524544
#
#  leaky_re_lu_43 (LeakyReLU)  (None, 7, 7, 256)         0
#
#  dropout_12 (Dropout)        (None, 7, 7, 256)         0
#
#  flatten_8 (Flatten)         (None, 12544)             0
#
#  dense_17 (Dense)            (None, 1)                 12545
#
# =================================================================
# Total params: 539,265
# Trainable params: 539,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen15, d=disc15, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 42s 19ms/step - d_loss: 0.6451 - g_loss: 0.7940

# %%
name = 'Model_16-Sig-OneDrop'
model16 = model.ModelSettings(model_name=name,
                             gen_filter=5,
                             disc_filter=5,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen16, disc16 = model.build(model16)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 100)]             0
#
#  dense_18 (Dense)            (None, 3136)              316736
#
#  leaky_re_lu_47 (LeakyReLU)  (None, 3136)              0
#
#  reshape_9 (Reshape)         (None, 7, 7, 64)          0
#
#  conv2d_transpose_27 (Conv2D  (None, 14, 14, 32)       32800
#  Transpose)
#
#  leaky_re_lu_45 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  conv2d_transpose_28 (Conv2D  (None, 28, 28, 16)       8208
#  Transpose)
#
#  leaky_re_lu_46 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  conv2d_transpose_29 (Conv2D  (None, 28, 28, 1)        145
#  Transpose)
#
# =================================================================
# Total params: 357,889
# Trainable params: 357,889
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 16)        272
#
#  leaky_re_lu_49 (LeakyReLU)  (None, 14, 14, 16)        0
#
#  conv2d_18 (Conv2D)          (None, 7, 7, 32)          8224
#
#  leaky_re_lu_48 (LeakyReLU)  (None, 7, 7, 32)          0
#
#  flatten_9 (Flatten)         (None, 1568)              0
#
#  dropout_14 (Dropout)        (None, 1568)              0
#
#  dense_19 (Dense)            (None, 1)                 1569
#
# =================================================================
# Total params: 10,065
# Trainable params: 10,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen16, d=disc16, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 13s 6ms/step - d_loss: 0.6879 - g_loss: 0.6579

# %%
name = 'Model_17-Sig-OneDrop'
model17 = model.ModelSettings(model_name=name,
                             gen_filter=6,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen17, disc17 = model.build(model7)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 100)]             0
#
#  dense_20 (Dense)            (None, 6272)              633472
#
#  leaky_re_lu_52 (LeakyReLU)  (None, 6272)              0
#
#  reshape_10 (Reshape)        (None, 7, 7, 128)         0
#
#  conv2d_transpose_30 (Conv2D  (None, 14, 14, 64)       131136
#  Transpose)
#
#  leaky_re_lu_50 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  conv2d_transpose_31 (Conv2D  (None, 28, 28, 32)       32800
#  Transpose)
#
#  leaky_re_lu_51 (LeakyReLU)  (None, 28, 28, 32)        0
#
#  conv2d_transpose_32 (Conv2D  (None, 28, 28, 1)        289
#  Transpose)
#
# =================================================================
# Total params: 797,697
# Trainable params: 797,697
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 32)        544
#
#  leaky_re_lu_54 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  conv2d_20 (Conv2D)          (None, 7, 7, 64)          32832
#
#  leaky_re_lu_53 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  flatten_10 (Flatten)        (None, 3136)              0
#
#  dropout_15 (Dropout)        (None, 3136)              0
#
#  dense_21 (Dense)            (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen17, d=disc17, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 16s 7ms/step - d_loss: 0.5491 - g_loss: 1.0072

# %%
name = 'Model_18-Sig-OneDrop'
model18 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=6,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen18, disc18 = model.build(model18)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 100)]             0
#
#  dense_22 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_57 (LeakyReLU)  (None, 12544)             0
#
#  reshape_11 (Reshape)        (None, 7, 7, 256)         0
#
#  conv2d_transpose_33 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_55 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_34 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_56 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_35 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 32)        544
#
#  leaky_re_lu_59 (LeakyReLU)  (None, 14, 14, 32)        0
#
#  conv2d_22 (Conv2D)          (None, 7, 7, 64)          32832
#
#  leaky_re_lu_58 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  flatten_11 (Flatten)        (None, 3136)              0
#
#  dropout_16 (Dropout)        (None, 3136)              0
#
#  dense_23 (Dense)            (None, 1)                 3137
#
# =================================================================
# Total params: 36,513
# Trainable params: 36,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen18, d=disc18, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 27s 12ms/step - d_loss: 0.6925 - g_loss: 0.6507

# %%
name = 'Model_19-Sig-OneDrop'
model19 = model.ModelSettings(model_name=name,
                             gen_filter=7,
                             disc_filter=7,
                             num_conv_layers=2,
                             kernel=4,
                             stride=2,
                             output=channel,
                             img_shape=img_shape,
                             dim=7,
                             latent_dim=latent_dim,
                             filter_mode=2,
                             is_multi_drop=False,
                             is_batchnorm=False,
                             is_tanh=False
                             )
gen19, disc19 = model.build(model19)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 100)]             0
#
#  dense_24 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_62 (LeakyReLU)  (None, 12544)             0
#
#  reshape_12 (Reshape)        (None, 7, 7, 256)         0
#
#  conv2d_transpose_36 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_60 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_37 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_61 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_38 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 64)        1088
#
#  leaky_re_lu_64 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  conv2d_24 (Conv2D)          (None, 7, 7, 128)         131200
#
#  leaky_re_lu_63 (LeakyReLU)  (None, 7, 7, 128)         0
#
#  flatten_12 (Flatten)        (None, 6272)              0
#
#  dropout_17 (Dropout)        (None, 6272)              0
#
#  dense_25 (Dense)            (None, 1)                 6273
#
# =================================================================
# Total params: 138,561
# Trainable params: 138,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen19, d=disc19, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 30s 14ms/step - d_loss: 0.6751 - g_loss: 0.6996

# %%
name = 'Model_20-Sig-OneDrop'
model20 = model.ModelSettings(model_name=name,
                              gen_filter=7,
                              disc_filter=8,
                              num_conv_layers=2,
                              kernel=4,
                              stride=2,
                              output=channel,
                              img_shape=img_shape,
                              dim=7,
                              latent_dim=latent_dim,
                              filter_mode=2,
                              is_multi_drop=False,
                              is_batchnorm=False,
                              is_tanh=False
                              )
gen20, disc20 = model.build(model20)
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 100)]             0
#
#  dense_26 (Dense)            (None, 12544)             1266944
#
#  leaky_re_lu_67 (LeakyReLU)  (None, 12544)             0
#
#  reshape_13 (Reshape)        (None, 7, 7, 256)         0
#
#  conv2d_transpose_39 (Conv2D  (None, 14, 14, 128)      524416
#  Transpose)
#
#  leaky_re_lu_65 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_40 (Conv2D  (None, 28, 28, 64)       131136
#  Transpose)
#
#  leaky_re_lu_66 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_41 (Conv2D  (None, 28, 28, 1)        577
#  Transpose)
#
# =================================================================
# Total params: 1,923,073
# Trainable params: 1,923,073
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 128)       2176
#
#  leaky_re_lu_69 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_26 (Conv2D)          (None, 7, 7, 256)         524544
#
#  leaky_re_lu_68 (LeakyReLU)  (None, 7, 7, 256)         0
#
#  flatten_13 (Flatten)        (None, 12544)             0
#
#  dropout_18 (Dropout)        (None, 12544)             0
#
#  dense_27 (Dense)            (None, 1)                 12545
#
# =================================================================
# Total params: 539,265
# Trainable params: 539,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
g = gan.GAN(g=gen20, d=disc20, b_size=batch_size, l_dim=latent_dim)
g.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
g.fit(dataset, epochs=epochs, callbacks = [gan.GANCallback(num_img=n_images,iFreq=image_freq, seed=s, loc=image_dir, name=name)])
# Out:
# None
# 2188/2188 [==============================] - 35s 16ms/step - d_loss: 0.6503 - g_loss: 0.7835
